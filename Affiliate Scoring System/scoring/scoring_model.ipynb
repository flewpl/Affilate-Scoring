# %% [markdown]
# # Scoring system

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mysql.connector as mysql
from affiliate_scoring import evaluate_partners, BENCHMARKS
from scoring_ml import ml_predict

# %%
connection = mysql.connect(
    host='127.0.0.1',
    user='flewpl',
    password='root',
    database='scoring'
)

# %% [markdown]
# pull a database

# %%
query = "SELECT * FROM affiliates"
data = pd.read_sql(query, connection)
# Out:
# C:\Users\maxim\AppData\Local\Temp\ipykernel_32764\2612304377.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, connection)

# %%
data.head()
# Out:
#    id                             name profile_name  clicks  registrations  \
# 0   1  Rodriguez, Figueroa and Sanchez          SEO   13456           1095
# 1   2                        Doyle Ltd          SEO   31129           1517
# 2   3    Mcclain, Miller and Henderson          SEO    8906            393
# 3   4                   Davis and Sons          SEO   15307           1226
# 4   5      Guzman, Hoffman and Baldwin          SEO   23991           2005
#
#    ftd_count  reg_rate  ftd_rate  ngr_per_ftd  total_ngr  retention_30d
# 0        415    0.0814    0.3793       135.61    56276.6         0.6611
# 1        623    0.0487    0.4108       165.23   102939.0         0.6018
# 2        113    0.0442    0.2894       141.12    15947.0         0.6674
# 3        388    0.0801    0.3172       114.36    44372.0         0.6723
# 4        679    0.0836    0.3387       157.13   106690.0         0.5495

# %% [markdown]
# # Using  scoring system

# %% [markdown]
# ### Firstly, rule-based scoring

# %%
data["evaluation_results"] = data.apply(evaluate_partners, axis=1)
data['final_status'] = data['evaluation_results'].apply(lambda x: x.get('final_status'))
print(data.iloc[500:506])
# Out:
#       id                             name profile_name  clicks  registrations  \
# 500  501  Rivera, Martinez and Richardson          PPC   27103            934
# 501  502                       Paul-Kline          PPC  101850           1904
# 502  503                     Morgan-Lopez          PPC  114569           3543
# 503  504         Jimenez, Glass and Stone          PPC   77793           1377
# 504  505                       Acosta Inc          PPC   15631            281
# 505  506                   Morrison-Short          PPC   35668           1084
#
#      ftd_count  reg_rate  ftd_rate  ngr_per_ftd  total_ngr  retention_30d  \
# 500        261    0.0345    0.2798       109.07    28467.2         0.2351
# 501        545    0.0187    0.2866        94.89    51716.9         0.3366
# 502        833    0.0309    0.2352        52.92    44085.6         0.3282
# 503        265    0.0177    0.1928        81.58    21619.7         0.3020
# ...

# %% [markdown]
# ### Now, checking smart fraud using ML models

# %%
ml_predict(data)
# Out:
# F1 macro (CV): 1.000 В± 0.000
# Differences: 0 from 1000
